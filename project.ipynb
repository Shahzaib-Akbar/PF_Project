# %%
import pandas as pd

# %%
df = pd.read_csv("anxiety data.csv")

# %% [markdown]
# # PF Project
# # Submitted By: Shahzaib Akbar
# # Roll No: SU92-BSAIM-F24-132
# # Submitted To: Sir Ahmad Hassan

# %% [markdown]
# # Data Cleaning:

# %%
df.head(5)
# Out:
#    ID  Age  Gender Occupation  Sleep Hours  Physical Activity (hrs/week)  \
# 0   1   56  Female      Other          9.6                           8.3
# 1   2   46    Male    Teacher          6.4                           7.3
# 2   3   32  Female     Doctor          6.9                           1.0
# 3   4   60    Male     Doctor          9.2                           3.7
# 4   5   25    Male    Student          9.2                           2.5
#
#    Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week) Smoking  \
# 0                       175                                  6      No
# 1                        97                                  6      No
# 2                       467                                 14      No
# 3                       471                                 16      No
# 4                       364                                  2      No
#
#   Family History of Anxiety  Stress Level (1-10)  \
# ...

# %%
df.tail(5)
# Out:
#           ID  Age  Gender Occupation  Sleep Hours  \
# 11995  11996   28    Male   Engineer          4.4
# 11996  11997   49  Female     Doctor          9.9
# 11997  11998   23  Female    Student          9.8
# 11998  11999   52    Male    Teacher          5.9
# 11999  12000   50    Male    Teacher          6.6
#
#        Physical Activity (hrs/week)  Caffeine Intake (mg/day)  \
# 11995                           4.1                       360
# 11996                           2.2                       433
# 11997                           8.1                       140
# 11998                           6.6                       114
# 11999                           7.8                       114
#
#        Alcohol Consumption (drinks/week) Smoking Family History of Anxiety  \
# 11995                                  1     Yes                       Yes
# 11996                                  4      No                       Yes
# ...

# %%
print(df)
# Out:
#           ID  Age  Gender Occupation  Sleep Hours  \
# 0          1   56  Female      Other          9.6
# 1          2   46    Male    Teacher          6.4
# 2          3   32  Female     Doctor          6.9
# 3          4   60    Male     Doctor          9.2
# 4          5   25    Male    Student          9.2
# ...      ...  ...     ...        ...          ...
# 11995  11996   28    Male   Engineer          4.4
# 11996  11997   49  Female     Doctor          9.9
# 11997  11998   23  Female    Student          9.8
# 11998  11999   52    Male    Teacher          5.9
# 11999  12000   50    Male    Teacher          6.6
#
#        Physical Activity (hrs/week)  Caffeine Intake (mg/day)  \
# 0                               8.3                       175
# 1                               7.3                        97
# 2                               1.0                       467
# 3                               3.7                       471
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ID                                 12000 non-null  int64
#  1   Age                                12000 non-null  int64
#  2   Gender                             12000 non-null  object
#  3   Occupation                         12000 non-null  object
#  4   Sleep Hours                        12000 non-null  float64
#  5   Physical Activity (hrs/week)       12000 non-null  float64
#  6   Caffeine Intake (mg/day)           12000 non-null  int64
#  7   Alcohol Consumption (drinks/week)  12000 non-null  int64
#  8   Smoking                            12000 non-null  object
#  9   Family History of Anxiety          12000 non-null  object
#  10  Stress Level (1-10)                12000 non-null  int64
# ...

# %%
df.describe()
# Out:
#                 ID          Age   Sleep Hours  Physical Activity (hrs/week)  \
# count  12000.00000  12000.00000  12000.000000                  12000.000000
# mean    6000.50000     40.96675      6.482650                      5.030892
# std     3464.24595     13.47328      2.014885                      2.889000
# min        1.00000     18.00000      3.000000                      0.000000
# 25%     3000.75000     29.00000      4.800000                      2.500000
# 50%     6000.50000     41.00000      6.500000                      5.000000
# 75%     9000.25000     53.00000      8.200000                      7.525000
# max    12000.00000     64.00000     10.000000                     10.000000
#
#        Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week)  \
# count              12000.000000                       12000.000000
# mean                 246.696083                           9.492833
# std                  144.487071                           5.769364
# ...

# %%
df.iloc[2]
# Out:
# ID                                        3
# Age                                      32
# Gender                               Female
# Occupation                           Doctor
# Sleep Hours                             6.9
# Physical Activity (hrs/week)            1.0
# Caffeine Intake (mg/day)                467
# Alcohol Consumption (drinks/week)        14
# Smoking                                  No
# Family History of Anxiety                No
# Stress Level (1-10)                       2
# Heart Rate (bpm during attack)           60
# Breathing Rate (breaths/min)             34
# Sweating Level (1-5)                      1
# Dizziness                                No
# Medication                               No
# Therapy Sessions (per month)              7
# Recent Major Life Event                 Yes
# Diet Quality (1-10)                      10
# Severity of Anxiety Attack (1-10)         5
# Name: 2, dtype: object

# %%
df.iloc[5]
# Out:
# ID                                         6
# Age                                       38
# Gender                                  Male
# Occupation                           Student
# Sleep Hours                              6.7
# Physical Activity (hrs/week)             9.9
# Caffeine Intake (mg/day)                 194
# Alcohol Consumption (drinks/week)         16
# Smoking                                   No
# Family History of Anxiety                Yes
# Stress Level (1-10)                        2
# Heart Rate (bpm during attack)           174
# Breathing Rate (breaths/min)              25
# Sweating Level (1-5)                       3
# Dizziness                                 No
# Medication                               Yes
# Therapy Sessions (per month)               2
# Recent Major Life Event                  Yes
# Diet Quality (1-10)                        1
# Severity of Anxiety Attack (1-10)          8
# Name: 5, dtype: object

# %%
df["Age"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Age'>

# %%
df['Age'].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='Age'>

# %%
df['Age'].value_counts().plot(kind="area")
# Out:
# <Axes: xlabel='Age'>

# %%
df['Age'].value_counts().plot(kind="box")
# Out:
# <Axes: >

# %%
df['Age'].value_counts().plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
df['Age'].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df['Age'].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='Age'>

# %%
df['Age'].value_counts().plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
df.describe(include="all")
# Out:
#                  ID          Age  Gender  Occupation   Sleep Hours  \
# count   12000.00000  12000.00000   12000       12000  12000.000000
# unique          NaN          NaN       3           6           NaN
# top             NaN          NaN  Female  Unemployed           NaN
# freq            NaN          NaN    5809        2139           NaN
# mean     6000.50000     40.96675     NaN         NaN      6.482650
# std      3464.24595     13.47328     NaN         NaN      2.014885
# min         1.00000     18.00000     NaN         NaN      3.000000
# 25%      3000.75000     29.00000     NaN         NaN      4.800000
# 50%      6000.50000     41.00000     NaN         NaN      6.500000
# 75%      9000.25000     53.00000     NaN         NaN      8.200000
# max     12000.00000     64.00000     NaN         NaN     10.000000
#
#         Physical Activity (hrs/week)  Caffeine Intake (mg/day)  \
# count                   12000.000000              12000.000000
# ...

# %%
a= df['Age']
print(a)
# Out:
# 0        56
# 1        46
# 2        32
# 3        60
# 4        25
#          ..
# 11995    28
# 11996    49
# 11997    23
# 11998    52
# 11999    50
# Name: Age, Length: 12000, dtype: int64

# %% [markdown]
# # Preprocessing:

# %%
df.isnull()
# Out:
#           ID    Age  Gender  Occupation  Sleep Hours  \
# 0      False  False   False       False        False
# 1      False  False   False       False        False
# 2      False  False   False       False        False
# 3      False  False   False       False        False
# 4      False  False   False       False        False
# ...      ...    ...     ...         ...          ...
# 11995  False  False   False       False        False
# 11996  False  False   False       False        False
# 11997  False  False   False       False        False
# 11998  False  False   False       False        False
# 11999  False  False   False       False        False
#
#        Physical Activity (hrs/week)  Caffeine Intake (mg/day)  \
# 0                             False                     False
# 1                             False                     False
# 2                             False                     False
# 3                             False                     False
# ...

# %%
df.sample(6)
# Out:
#         ID  Age  Gender  Occupation  Sleep Hours  \
# 7351  7352   22    Male       Other          5.7
# 6817  6818   32  Female    Engineer          5.1
# 3817  3818   61    Male  Unemployed          4.1
# 7951  7952   23    Male       Other          8.5
# 5813  5814   38    Male     Student          7.6
# 6547  6548   41   Other      Doctor          4.2
#
#       Physical Activity (hrs/week)  Caffeine Intake (mg/day)  \
# 7351                           8.4                       276
# 6817                           8.7                       382
# 3817                           6.1                       439
# 7951                           0.7                       236
# 5813                           7.9                       429
# 6547                           6.8                       158
#
#       Alcohol Consumption (drinks/week) Smoking Family History of Anxiety  \
# 7351                                 16      No                        No
# ...

# %% [markdown]
# # Slicing in code:

# %%
df[2:3]
# Out:
#    ID  Age  Gender Occupation  Sleep Hours  Physical Activity (hrs/week)  \
# 2   3   32  Female     Doctor          6.9                           1.0
#
#    Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week) Smoking  \
# 2                       467                                 14      No
#
#   Family History of Anxiety  Stress Level (1-10)  \
# 2                        No                    2
#
#    Heart Rate (bpm during attack)  Breathing Rate (breaths/min)  \
# 2                              60                            34
#
#    Sweating Level (1-5) Dizziness Medication  Therapy Sessions (per month)  \
# 2                     1        No         No                             7
#
#   Recent Major Life Event  Diet Quality (1-10)  \
# 2                     Yes                   10
#
#    Severity of Anxiety Attack (1-10)
# 2                                  5

# %%
df[2:5:3]
# Out:
#    ID  Age  Gender Occupation  Sleep Hours  Physical Activity (hrs/week)  \
# 2   3   32  Female     Doctor          6.9                           1.0
#
#    Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week) Smoking  \
# 2                       467                                 14      No
#
#   Family History of Anxiety  Stress Level (1-10)  \
# 2                        No                    2
#
#    Heart Rate (bpm during attack)  Breathing Rate (breaths/min)  \
# 2                              60                            34
#
#    Sweating Level (1-5) Dizziness Medication  Therapy Sessions (per month)  \
# 2                     1        No         No                             7
#
#   Recent Major Life Event  Diet Quality (1-10)  \
# 2                     Yes                   10
#
#    Severity of Anxiety Attack (1-10)
# 2                                  5

# %%
df[["Age"]][1:3]
# Out:
#    Age
# 1   46
# 2   32

# %% [markdown]
# # std() Standard deviation:

# %%
df["Age"].std()
# Out:
# 13.473279922751711

# %% [markdown]
# # var() Variance calculation:

# %%
df["Age"].var()
# Out:
# 181.52927187682437

# %% [markdown]
# # Adding a new column :

# %%
df["Age"]=5
df
# Out:
#           ID  Age  Gender Occupation  Sleep Hours  \
# 0          1    5  Female      Other          9.6
# 1          2    5    Male    Teacher          6.4
# 2          3    5  Female     Doctor          6.9
# 3          4    5    Male     Doctor          9.2
# 4          5    5    Male    Student          9.2
# ...      ...  ...     ...        ...          ...
# 11995  11996    5    Male   Engineer          4.4
# 11996  11997    5  Female     Doctor          9.9
# 11997  11998    5  Female    Student          9.8
# 11998  11999    5    Male    Teacher          5.9
# 11999  12000    5    Male    Teacher          6.6
#
#        Physical Activity (hrs/week)  Caffeine Intake (mg/day)  \
# 0                               8.3                       175
# 1                               7.3                        97
# 2                               1.0                       467
# 3                               3.7                       471
# ...

# %% [markdown]
# # Remove a column:

# %%
df.drop(columns=["Age"],inplace=True)

# %% [markdown]
# # Add a row :

# %%
a=pd.DataFrame({"Age":5,
                "gender":'male',
                "Sleep Hours":"5"},
                index=[5])
a
df=pd.concat([a,df])
df
# Out:
#        Age gender Sleep Hours       ID  Gender Occupation  \
# 5      5.0   male           5      NaN     NaN        NaN
# 0      NaN    NaN         9.6      1.0  Female      Other
# 1      NaN    NaN         6.4      2.0    Male    Teacher
# 2      NaN    NaN         6.9      3.0  Female     Doctor
# 3      NaN    NaN         9.2      4.0    Male     Doctor
# ...    ...    ...         ...      ...     ...        ...
# 11995  NaN    NaN         4.4  11996.0    Male   Engineer
# 11996  NaN    NaN         9.9  11997.0  Female     Doctor
# 11997  NaN    NaN         9.8  11998.0  Female    Student
# 11998  NaN    NaN         5.9  11999.0    Male    Teacher
# 11999  NaN    NaN         6.6  12000.0    Male    Teacher
#
#        Physical Activity (hrs/week)  Caffeine Intake (mg/day)  \
# 5                               NaN                       NaN
# 0                               8.3                     175.0
# 1                               7.3                      97.0
# ...

# %% [markdown]
# # Data Save:

# %%
import pandas as pd
df= pd.read_csv("anxiety data.csv")
df
df.to_excel("newdata.xlsx", sheet_name= "newsheet")
